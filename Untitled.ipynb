# %%
SCORING_CONFIG = {
    "MATCH_POOL_BASE": 680,
    "PERFECT_SCORE_BONUS": 680,
    "HALF_PERFECT_BONUS": 40,
    "AWAY_WIN_BONUS": 30,
    "DRAW_BONUS": 100,
    "OFFENSIVE_BONUS_VALUE": 15,
    "DEFENSIVE_BONUS_VALUE": 15,
    "BONUS_MALUS": -3,
    "DIFF_TABLE": {0: 15, 1: 12, 2: 10, 3: 8, 4: 6, 5: 4, 6: 2, 7: 1},
    "SUM_TABLE": {0: 8, 1: 6, 2: 5, 3: 4, 4: 3, 5: 2, 6: 1},
}

# %%
diff = 1

# %%
SCORING_CONFIG['DIFF_TABLE'][diff]
# Out:
# 12

# %%
SCORING_CONFIG['DIFF_TABLE'].keys()
# Out:
# dict_keys([0, 1, 2, 3, 4, 5, 6, 7])

# %%
def fct(diff):
    if diff in SCORING_CONFIG['DIFF_TABLE'].keys():
        return SCORING_CONFIG['DIFF_TABLE'][diff]

# %%
fct(1)
# Out:
# 12

# %%
fct(2)
# Out:
# 10
